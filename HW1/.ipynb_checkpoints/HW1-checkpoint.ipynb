# %%
import pandas as pd

# 讀取 CSV 檔案，指定第一欄為索引
df = pd.read_csv('11th gen intel.csv', index_col=0)

# 將資料儲存成新的 CSV 檔案，排除索引欄位
df.to_csv('new_file.csv', index=False)
df
# Out:
#                Model  Cores   Threads Clock rate_base Clock rate_max  \
# Processor
# Core i9       11900K       8       16         3.5 GHz        4.8 GHz
# Core i9      11900KF       8       16         3.5 GHz        4.8 GHz
# Core i9        11900       8       16         2.5 GHz        4.7 GHz
# Core i9       11900F       8       16         2.5 GHz        4.7 GHz
# Core i9       11900T       8       16         1.5 GHz        3.7 GHz
# ...              ...     ...      ...             ...            ...
# Core i3       1110G4       2        4         1.7 GHz        3.9 GHz
# Pentium    Gold 7505       2        4         2.0 GHz            NaN
# Celeron       6600HE       2        2         2.6 GHz            NaN
# Celeron         6305       2        2         1.8 GHz            NaN
# Celeron        6305E       2        2         1.8 GHz            NaN
#
#           Clock rate_turbo Clock rate_turbo boost     IGPU IGPU_Clock  \
# Processor
# Core i9            5.1 GHz                5.2 GHz  UHD 750    1.3 GHz
# Core i9            5.1 GHz                5.2 GHz      NaN        NaN
# Core i9            5.0 GHz                5.1 GHz  UHD 750    1.3 GHz
# Core i9            5.0 GHz                5.1 GHz      NaN        NaN
# Core i9            4.8 GHz                4.9 GHz  UHD 750    1.3 GHz
# ...                    ...                    ...      ...        ...
# Core i3                NaN                    NaN     UHD    1.10 GHz
# Pentium                NaN                    NaN     UHD    1.25 GHz
# Celeron                NaN                    NaN     UHD    1.10 GHz
# Celeron                NaN                    NaN     UHD    1.25 GHz
# Celeron                NaN                    NaN     UHD    1.25 GHz
#
#            IGPU_EUs  Smart cache_MB  TDP_Watts  Price     Socket   Launch
# Processor
# Core i9        32.0              16        125  $539    LGA 1200  Q1 2021
# Core i9         NaN              16        125  $513    LGA 1200  Q1 2021
# Core i9        32.0              16         65  $439    LGA 1200  Q1 2021
# Core i9         NaN              16         65  $422    LGA 1200  Q1 2021
# Core i9        32.0              16         35  $439    LGA 1200  Q1 2021
# ...             ...             ...        ...    ...        ...      ...
# Core i3        48.0               6          7    NaN  FCBGA1598  Q3 2020
# Pentium        48.0               4          7    NaN  FCBGA1449  Q4 2020
# Celeron        16.0               8         35    NaN  FCBGA1787  Q3 2021
# Celeron        48.0               4         15    NaN  FCBGA1449  Q4 2020
# Celeron        48.0               4         15    NaN  FCBGA1449  Q4 2020
#
# [75 rows x 15 columns]

# %%
#(1)所有11代i5處理器
import pandas as pd

# 讀取 CSV 檔案，指定第一欄為索引
df = pd.read_csv('11th gen intel.csv', index_col=0)

# 使用 loc 函數定位資料，其中 'column_name' 和 row_index 是欄位名稱和列索引
data = df.loc['Core i5', 'Model']

# 輸出資料
print(data)
# Out:
# Processor
# Core i5     11600K
# Core i5    11600KF
# Core i5      11600
# Core i5     11600T
# Core i5      11500
# Core i5     11500T
# Core i5      11400
# Core i5     11400F
# Core i5     11400T
# Core i5     11500H
# Core i5    11500HE
# Core i5     11400H
# Core i5     11260H
# Core i5     11320H
# Core i5    11300H
# Core i5     1155G7
# Core i5     1145G7
# Core i5    1145G7E
# Core i5    1145G7E
# Core i5     1135G7
# Core i5     1130G7
# Core i5     1140G7
# Name: Model, dtype: object

# %%
#(2)所有有顯示晶片的處理器
import pandas as pd

# 讀取 CSV 檔案，指定第一欄為索引
df = pd.read_csv('11th gen intel.csv', index_col=0)

# 指定要輸出的欄位
columns_to_output = ['Model','IGPU']

# 使用 dropna 函數移除所有包含 NaN 值的列
df = df[columns_to_output].dropna()

# 輸出 DataFrame
print(df)
# Out:
#                Model     IGPU
# Processor
# Core i9       11900K  UHD 750
# Core i9        11900  UHD 750
# Core i9       11900T  UHD 750
# Core i7       11700K  UHD 750
# Core i7        11700  UHD 750
# ...              ...      ...
# Core i3       1110G4     UHD
# Pentium    Gold 7505     UHD
# Celeron       6600HE     UHD
# Celeron         6305     UHD
# Celeron        6305E     UHD
#
# [69 rows x 2 columns]

# %%
#(3)有最高頻率的處理器
import pandas as pd

# 讀取 CSV 檔案，指定第一欄為索引
df = pd.read_csv('11th gen intel.csv', index_col=0)

# 指定要找最大值的欄位名稱
column_to_find_max = 'Clock rate_base'

# 找到最大值
max_value = df[column_to_find_max].max()

# 建立布林遮罩，選擇符合最大值的那列資料
mask = df[column_to_find_max] == max_value
max_rows = df[mask]

subset = max_rows['Model']

print(f"Fastest clock rate：{max_value}")
print("CPUs with fastest clock rate：")
print(subset)
# Out:
# Fastest clock rate：3.9 GHz
# CPUs with fastest clock rate：
# Processor
# Core i5     11600K
# Core i5    11600KF
# Name: Model, dtype: object

# %%
#(4)大於32個處理單元顯示晶片的處理器
import pandas as pd

# 讀取 CSV 檔案，指定第一欄為索引
df = pd.read_csv('11th gen intel.csv', index_col=0)

# 選擇符合條件的資料
df_filtered = df[df['IGPU_EUs'] > 32]

subset = df_filtered[['Model', 'IGPU_EUs']]


# 輸出符合條件的資料
print(subset )
# Out:
#                Model  IGPU_EUs
# Processor
# Core i7       11390H      96.0
# Core i7       11375H      96.0
# Core i7       11370H      96.0
# Core i7       11370H      96.0
# Core i7      11375H       96.0
# Core i7       1195G7      96.0
# Core i7       1195G7      96.0
# Core i7      1185GRE      96.0
# Core i7      1185G7E      96.0
# Core i7       1165G7      96.0
# Core i7       1185G7      96.0
# Core i7      1165G7       96.0
# Core i7       1180G7      96.0
# Core i7      1160G7       96.0
# Core i5       11320H      96.0
# Core i5      11300H       80.0
# Core i5       1155G7      80.0
# Core i5       1145G7      80.0
# Core i5      1145G7E      80.0
# Core i5      1145G7E      80.0
# Core i5       1135G7      80.0
# Core i5       1130G7      80.0
# Core i5       1140G7      80.0
# Core i3       1125G4      48.0
# Core i3       1125G4      48.0
# Core i3       1120G4      48.0
# Core i3      1115GRE      48.0
# Core i3      1115G4E      48.0
# Core i3       1115G4      48.0
# Core i3       1115G4      48.0
# Core i3       1110G4      48.0
# Pentium    Gold 7505      48.0
# Celeron         6305      48.0
# Celeron        6305E      48.0

# %%
#(5)功號小於7瓦的處理器
import pandas as pd

# 讀取 CSV 檔案，指定第一欄為索引
df = pd.read_csv('11th gen intel.csv', index_col=0)

# 選擇符合條件的資料
df_filtered = df[df['TDP_Watts'] < 10]

subset = df_filtered[['Model', 'TDP_Watts']]


# 輸出符合條件的資料
print(subset )
# Out:
#                Model  TDP_Watts
# Processor
# Core i7       1180G7          7
# Core i7      1160G7           7
# Core i5       1140G7          7
# Core i3       1120G4          7
# Core i3       1110G4          7
# Pentium    Gold 7505          7

# %%
#(6)哪個時段發表最多處理器
import pandas as pd

# 讀取 CSV 檔案，指定第一欄為索引
df = pd.read_csv('11th gen intel.csv', index_col=0)

# 使用value_counts()方法，計算每個值出現的次數
counts = df['Launch'].value_counts()

# 找出出現次數最多的值，並輸出
most_common = counts.idxmax()
subset = df.loc[df['Launch'] == most_common, ['Model', 'Launch']]
print(subset)
# Out:
#              Model   Launch
# Processor
# Core i9     11900K  Q1 2021
# Core i9    11900KF  Q1 2021
# Core i9      11900  Q1 2021
# Core i9     11900F  Q1 2021
# Core i9     11900T  Q1 2021
# Core i7     11700K  Q1 2021
# Core i7    11700KF  Q1 2021
# Core i7      11700  Q1 2021
# Core i7     11700F  Q1 2021
# Core i7     11700T  Q1 2021
# Core i5     11600K  Q1 2021
# Core i5    11600KF  Q1 2021
# Core i5      11600  Q1 2021
# Core i5     11600T  Q1 2021
# Core i5      11500  Q1 2021
# Core i5     11500T  Q1 2021
# Core i5      11400  Q1 2021
# Core i5     11400F  Q1 2021
# Core i5     11400T  Q1 2021
# Core i7     11375H  Q1 2021
# Core i7     11370H  Q1 2021
# Core i7     1180G7  Q1 2021
# Core i5    11300H   Q1 2021
# Core i5     1145G7  Q1 2021
# Core i5     1140G7  Q1 2021
# Core i3     1125G4  Q1 2021
# Core i3     1125G4  Q1 2021
# Core i3     1120G4  Q1 2021

# %%
#(7)快取不小於12MB且核心數不小於6的處理器
import pandas as pd

# 讀取 CSV 檔案，指定第一欄為索引
df = pd.read_csv('11th gen intel.csv', index_col=0)

# 選擇符合條件的資料
df_filtered = df[(df['Cores'] >= 6) & (df['Smart cache_MB'] >= 12)]

subset = df_filtered[['Cores','Smart cache_MB']]


# 輸出符合條件的資料
print(subset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cores'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3868\468874573.py in <module>
#       6
#       7 # 選擇符合條件的資料
# ----> 8 df_filtered = df[(df['Cores'] >= 6) & (df['Smart cache_MB'] >= 12)]
#       9
#      10 subset = df_filtered[['Cores','Smart cache_MB']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Cores'
